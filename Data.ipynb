# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
# %matplotlib inline
from warnings import simplefilter
from sklearn.exceptions import ConvergenceWarning
simplefilter("ignore", category=ConvergenceWarning)
import warnings
warnings.filterwarnings('ignore')
import pickle
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('flights.csv',usecols=[0,1,6,9,12,14,21,23,32])

# %%
df['month'] = pd.DatetimeIndex(df['fl_date']).month
df['month_day'] = pd.DatetimeIndex(df['fl_date']).day
df['week_day'] = pd.DatetimeIndex(df['fl_date']).weekday
df['year_day'] = pd.DatetimeIndex(df['fl_date']).dayofyear
df['dep_hour'] = pd.to_datetime(df['crs_dep_time'], format='%H%M', errors='coerce').dt.hour
df['arr_hour'] = pd.to_datetime(df['crs_arr_time'], format='%H%M', errors='coerce').dt.hour

# %%
df.head()
# Out:
#       fl_date mkt_unique_carrier tail_num origin dest  crs_dep_time
# 0  2019-08-30                 AS   N644QX    PAE  LAX          1600  \
# 1  2019-08-30                 AS   N644QX    LAX  PAE          1955
# 2  2019-08-30                 AS   N630QX    PAE  PDX           630
# 3  2019-08-30                 AS   N644QX    PDX  PAE           740
# 4  2019-08-30                 AS   N648QX    PAE  PDX          1320
#
#    crs_arr_time  arr_delay  distance  month  month_day  week_day  year_day
# 0          1850      -19.0       984      8         30         4       242  \
# 1          2250      -24.0       984      8         30         4       242
# 2           725      -18.0       161      8         30         4       242
# 3           840       -8.0       161      8         30         4       242
# 4          1415       15.0       161      8         30         4       242
#
#    dep_hour  arr_hour
# 0      16.0      18.0
# 1      19.0      22.0
# 2       6.0       7.0
# 3       7.0       8.0
# 4      13.0      14.0

# %%
df=df.drop(['crs_dep_time','crs_arr_time'], axis=1)

# %%
df.isnull().sum()
# Out:
# fl_date                    0
# mkt_unique_carrier         0
# tail_num               49269
# origin                     0
# dest                       0
# arr_delay             311744
# distance                   0
# month                      0
# month_day                  0
# week_day                   0
# year_day                   0
# dep_hour                2568
# arr_hour               48937
# dtype: int64

# %%
df.head()
# Out:
#       fl_date mkt_unique_carrier tail_num origin dest  arr_delay  distance
# 0  2019-08-30                 AS   N644QX    PAE  LAX      -19.0       984  \
# 1  2019-08-30                 AS   N644QX    LAX  PAE      -24.0       984
# 2  2019-08-30                 AS   N630QX    PAE  PDX      -18.0       161
# 3  2019-08-30                 AS   N644QX    PDX  PAE       -8.0       161
# 4  2019-08-30                 AS   N648QX    PAE  PDX       15.0       161
#
#    month  month_day  week_day  year_day  dep_hour  arr_hour
# 0      8         30         4       242      16.0      18.0
# 1      8         30         4       242      19.0      22.0
# 2      8         30         4       242       6.0       7.0
# 3      8         30         4       242       7.0       8.0
# 4      8         30         4       242      13.0      14.0

# %%
df.drop('year_day',axis=1,inplace=True)

# %%
df.to_csv('data.csv', index=False)
